# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
BabyNames_df = pd.read_csv('BABY_NAMES.zip')
BabyNames_df.head(50)
# Out:
#                        c:\users\sfsph\desktop\namesbystate\AK.TXT
# AK F 1910.0 Mary                                             14.0
#             Annie                                            12.0
#             Anna                                             10.0
#             Margaret                                          8.0
#             Helen                                             7.0
#             Elsie                                             6.0
#             Lucy                                              6.0
#             Dorothy                                           5.0
#      1911.0 Mary                                             12.0
#             Margaret                                          7.0
#             Ruth                                              7.0
#             Annie                                             6.0
#             Elizabeth                                         6.0
# ...
